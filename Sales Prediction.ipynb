# %%
import numpy as np
import pandas as pd

# %%
b= r"C:\Users\Bharat Batra\Downloads\advertising.csv"
df1= pd.read_csv(b)

# %%
df1
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df1.shape
# Out:
# (200, 4)

# %%
df1.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import seaborn as sns

# %%
sns.regplot(x="Sales", y="TV", data= df1)
# Out:
# <Axes: xlabel='Sales', ylabel='TV'>

# %%
sns.regplot(x="Sales", y= "Radio", data= df1)
# Out:
# <Axes: xlabel='Sales', ylabel='Radio'>

# %%
sns.regplot(x="Sales", y="Newspaper", data= df1)
# Out:
# <Axes: xlabel='Sales', ylabel='Newspaper'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
y= df1["Sales"].to_numpy()
df1.drop(columns= "Sales", inplace=True)

# %%
x= df1.to_numpy()

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=00.2, random_state=7)

reg= LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred= reg.predict(x_test)

acc= r2_score(y_test, pred)

# %%
pred
# Out:
# array([11.7725576 , 15.23562579,  7.08812427, 18.99766631,  7.22012639,
#        10.40244647,  7.9955541 , 12.07972676,  9.02947543, 13.4418986 ,
#         5.49425065, 15.93413681,  9.77965606,  9.49747882, 21.85492699,
#         6.17835801,  9.4591362 , 16.44682719, 18.2226662 , 10.66592377,
#        20.1271784 , 19.43110599, 11.04734724, 18.98156157, 12.59125662,
#        21.41754053, 24.67090774, 15.40712062, 21.52587839, 14.85664994,
#        14.19150595,  7.24179095, 16.05413919, 20.87872557, 20.61370694,
#        17.19132009,  9.17653452, 24.90656884, 11.6901426 , 13.84064233])

# %%
acc
# Out:
# 0.9259262684743649
